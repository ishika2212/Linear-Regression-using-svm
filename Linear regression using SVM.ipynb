# %% [markdown]
# **The Sparks Foundation:-** Data Science and Business Analytics Internship.
#
# **TASK 1:** Prediction using **Supervised Machine Learning**. In this task we have to predict the percentage of students based on the no. of study hours using linear regression, supervised machine learning algorithm.
#
# The steps are as follows:
#
#
# > Indented block

# %% [markdown]
# # **Importing data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading data from the remote line
url="http://bit.ly/w-data"
s_data = pd.read_csv(url)
print("Imported data successfully")
s_data.head(20)
# Out:
# Imported data successfully
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69

# %% [markdown]
# Now we will be ploting our data points in 2D graph to find any relationship between the data.

# %%
s_data.plot(x="Hours", y="Scores", style="o")
plt.title("Study Hours vs Percentage Score")
plt.xlabel("No of study hours")
plt.ylabel("Percentage Score")
plt.show()

# %% [markdown]
# From the above graph, we can conclude that there is positive relation between the number of hours studies and percentage of score. Now dividing the data into attributes and lables.

# %%
X=s_data.iloc[:,:-1].values
y=s_data.iloc[:,1].values

# %% [markdown]
# In the next step, we will use Scikit-Learn's built-in train_set_split() method to split our data into training and test sets.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # **Training the algorithm**

# %% [markdown]
# As we have splitted our data into training and testing sets, we will now train our algorithm.

# %%
from sklearn.linear_model import LinearRegression
R1=LinearRegression()
R1.fit(X,y)
print("Training the model")
# Out:
# Training the model

# %%
#plotting regression line
line=R1.coef_*X+R1.intercept_
plt.scatter(X,y)
plt.plot(X,line)
plt.show()

# %% [markdown]
# # **Making Predictions**

# %%
#testing data
print(X_test)
y_pred=R1.predict(X_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
#comparing actual vs predicted
df=pd.DataFrame({"Actual":y_test, "Predicted":y_pred})
df
# Out:
#    Actual  Predicted
# 0      20  17.147378
# 1      27  33.766244
# 2      69  74.824618
# 3      30  26.923182
# 4      62  60.160913

# %%
print("Training Score:",R1.score(X_train,y_train))
print("Testing Score: ",R1.score(X_test,y_test))
# Out:
# Training Score: 0.9512837351709387
# Testing Score:  0.9491748734859172

# %%
#plotting the actual and predicted value into bar graph
df.plot(kind="bar", figsize=(7,5))
plt.show()

# %%
#predicting for 9.25 hrs per day
hours=9.25
test=np.array([hours])
test=test.reshape(-1,1)
pred_val=R1.predict(test)
print("No. of hours=", hours)
print("Predicted Score=", pred_val[0])
# Out:
# No. of hours= 9.25
# Predicted Score= 92.9098547701573

# %% [markdown]
# # **Evaluating the Model**

# %%
import numpy as np
from sklearn import metrics
print("Mean Absolute Error: ",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error: ",metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Sqaured Error: ",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("Explained Variance Score: ",metrics.explained_variance_score(y_test,y_pred))
# Out:
# Mean Absolute Error:  4.071877793635605
# Mean Squared Error:  20.138948129940175
# Root Mean Sqaured Error:  4.487643939746131
# Explained Variance Score:  0.9515224335188082
